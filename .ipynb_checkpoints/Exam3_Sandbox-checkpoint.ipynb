# %%
#Imports and key definitions
# %pylab inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pylab import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Playground for helix question on Quiz 3

def x(val):
    return  # x function goes here

def y(val):
    return  # y function goes here

def z(val):
    return  # z function goes here

#3D plot
fig = plt.figure(figsize=(10,10)) #For large graphs, make sure to turn off scroll: Cell>Current Outputs>Toggle Scroll
ax = plt.axes(projection = '3d')
ax.view_init(90,0) #adjust the up/down and the left/right viewing angle
ax.set_xlabel('$X$')
ax.set_ylabel('$Y$')
ax.set_zlabel('$Z$')

#set p variable to graph continous function 
p = np.arange(0,1,.001)

#3D output
ax.plot(x(p),y(p),z(p),'b')
